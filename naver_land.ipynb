# %%
import requests

url = "https://m.land.naver.com/cluster/ajax/complexList?rletTpCd=APT&tradTpCd=A1&z=14&lat=37.482968&lon=127.0634&btm=37.4638949&lft=127.0319001&top=37.5020363&rgt=127.0948999&showR0=&totCnt=36&cortarNo=1168010300&isOnlyIsale=false"
res= requests.get(url, headers=headers)

#headers미 지정시 보안때문에 크롤링 불가 
headers= {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
} 

import json
data = json.loads(res.text)
items = data['result']

import pandas as pd
df = pd.DataFrame.from_dict(items)
df.head(100)
# Out:
#     hscpNo        hscpNm hscpTypeCd hscpTypeNm  totDongCnt  totHsehCnt  \
# 0   119219     개포래미안포레스트        A01        아파트          31        2296
# 1      483         대치2단지        A01        아파트          11        1758
# 2   112228      래미안블레스티지        A01        아파트          23        1957
# 3   113151      디에이치아너힐즈        A01        아파트          23        1320
# 4      419            대청        A01        아파트           6         822
# 5       28            경남        A01        아파트           9         678
# 6     8928          개포자이        A01        아파트           4         212
# 7     1321          현대2차        A01        아파트          13         558
# 8      881         더샵트리에        A01        아파트           2         232
# 9      667          우성3차        A01        아파트           5         405
# 10     770          우성6차        A01        아파트           8         270
# 11    1317          현대1차        A01        아파트           6         416
# ...
